# %% [markdown]
# <a href="https://colab.research.google.com/github/pyytryy/Analisis_Sentimen_Putri/blob/main/Scrapping_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Scrapping Data Dari Google Play Store**
#
# Pada proyek ini, saya akan melakukan scrapping data pada ulasan dan pendapat pengguna terkait aplikasi "Shoppe" di Play Store.
#
# Adapun untuk ID dari aplikasi dengan mudah ditemui dari link aplikasi tersebut

# %%
# !pip install google-play-scraper

# %% [markdown]
# # **Import Library**

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews, Sort, reviews_all
import pandas as pd  # Pandas untuk manipulasi dan analisis data
pd.options.mode.chained_assignment = None  # Menonaktifkan peringatan chaining

# %% [markdown]
# Mengambil 10000 ulasan dari aplikasi Shoppe di Play Store

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews_all, Sort

# Mengambil semua ulasan dari aplikasi dengan ID 'com.shopee.id' di Google Play Store.

scrapreview = reviews_all(
    'com.shopee.id',          # ID aplikasi
    lang='id',             # Bahasa ulasan (default: 'en')
    country='id',          # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT, # Urutan ulasan (default: Sort.MOST_RELEVANT)
    count=20000             # Jumlah maksimum ulasan yang ingin diambil
)

# %%
# Menyimpan ulasan dalam file CSV
import csv

with open('ulasan_aplikasi_shoppe.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom
    for review in scrapreview:
        writer.writerow([review['content']])  # Menulis konten ulasan ke dalam file CSV

# %%
data = pd.read_csv('/content/ulasan_aplikasi_shoppe.csv')
print (data.shape)
# Out:
# (148500, 1)
